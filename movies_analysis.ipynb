# %%
import pandas as pd

# %%
amazon_df= pd.read_csv("amazon prime movies.csv")
amazon_df
# Out:
#                Movie Name Language IMDb Rating Running Time Year of Release  \
# 0              John Rambo    Tamil           7   1 h 26 min            2008
# 1            American Pie  English           7   1 h 35 min            1999
# 2               Bombshell  English         6.8   1 h 48 min            2019
# 3              Love Birds    Tamil         5.1   2 h 40 min            1996
# 4                   Hippi   Telugu           5   2 h 20 min            2019
# ...                   ...      ...         ...          ...             ...
# 8122             Blackout  English         5.2   1 h 31 min            2014
# 8123               Loafer    Hindi         6.5    2 h 3 min            1973
# 8124          Remember Me  English         7.1   1 h 52 min            2010
# 8125                Khopa  Marathi        None  1 h 51 mins            2017
# 8126  Khandani Shafakhana    Hindi           4   2 h 14 min            2019
#
# ...

# %%
netflix_df=  pd.read_csv("netflix-rotten-tomatoes-metacritic-imdb.csv")
netflix_df
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...
